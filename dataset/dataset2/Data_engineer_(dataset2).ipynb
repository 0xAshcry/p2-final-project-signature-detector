# %%
import os
import cv2
import numpy as np

def preprocess_signature(image_path, size=(256, 256)):
    """Preprocessing gambar tanda tangan sebelum digunakan dalam model"""
    # Convert to grayscale
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  
    
    # Resize gambar
    image = cv2.resize(image, size, interpolation=cv2.INTER_AREA)  
    
    # Normalisasi dan thresholding
    image = image.astype(np.float32) / 255.0
    image_uint8 = (image * 255).astype(np.uint8)
    _, image = cv2.threshold(image_uint8, 200, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    
    # Pastikan latar belakang putih dan tanda tangan hitam
    if np.mean(image) < 127:  # Invert gambar jika perlu
        image = cv2.bitwise_not(image)
    
    # Ekstrak kontur dan fokus pada tanda tangan
    contours, _ = cv2.findContours(image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        x, y, w, h = cv2.boundingRect(max(contours, key=cv2.contourArea))
        image = image[y:y+h, x:x+w]  # Cropping
    
    # Inversi background (background hitam, tanda tangan putih)
    inverted_image = cv2.bitwise_not(image)
    
    return (image / 255.0).astype(np.float32), (inverted_image / 255.0).astype(np.float32)

def augment_image(image):
    augmented_images = []

    # PENCERAHAN GAMBAR (Brightness Adjustment)
    def brighten_image(img, alpha=1.5, beta=40):
        return cv2.convertScaleAbs(img, alpha=alpha, beta=beta)
    
    brightened = brighten_image(image)
    augmented_images.append(brightened)

    # VARIASI KONTRAS (Kontras lebih tinggi atau rendah)
    contrast_high = brighten_image(image, alpha=2.0, beta=0)
    contrast_low = brighten_image(image, alpha=0.8, beta=0)
    augmented_images.append(contrast_high)
    augmented_images.append(contrast_low)

    # DILATION & EROSION (Tapi lebih ringan dari sebelumnya)
    kernel = np.ones((2,2), np.uint8)
    dilated = cv2.dilate(image, kernel, iterations=1)
    eroded = cv2.erode(image, kernel, iterations=1)
    augmented_images.append(dilated)
    augmented_images.append(eroded)

    # RESIZE VARIATIONS
    resized_small = cv2.resize(image, (128, 128), interpolation=cv2.INTER_AREA)
    resized_large = cv2.resize(image, (512, 512), interpolation=cv2.INTER_LINEAR)
    augmented_images.append(resized_small)
    augmented_images.append(resized_large)

    # GAUSSIAN NOISE (Simulasi blur/gangguan sensor)
    def add_gaussian_noise(img, mean=0, sigma=20):
        noise = np.random.normal(mean, sigma, img.shape).astype(np.uint8)
        noisy_image = cv2.add(img, noise)
        return noisy_image

    gaussian_noisy = add_gaussian_noise(image)
    augmented_images.append(gaussian_noisy)

    # SALT & PEPPER NOISE (Simulasi bercak acak)
    def add_salt_and_pepper(img, salt_prob=0.02, pepper_prob=0.02):
        noisy_img = img.copy()
        total_pixels = img.size
        num_salt = int(total_pixels * salt_prob)
        num_pepper = int(total_pixels * pepper_prob)

        # Tambahkan salt (titik putih)
        coords = [np.random.randint(0, i - 1, num_salt) for i in img.shape]
        noisy_img[coords[0], coords[1]] = 255

        # Tambahkan pepper (titik hitam)
        coords = [np.random.randint(0, i - 1, num_pepper) for i in img.shape]
        noisy_img[coords[0], coords[1]] = 0

        return noisy_img

    salt_pepper_noisy = add_salt_and_pepper(image)
    augmented_images.append(salt_pepper_noisy)

    return augmented_images

def preprocess_all_images(input_folder, output_folder):
    """Proses semua gambar di folder input, simpan hasil di folder output"""
    os.makedirs(output_folder, exist_ok=True)
    
    for folder_name in os.listdir(input_folder):
        folder_path = os.path.join(input_folder, folder_name)
        
        if os.path.isdir(folder_path):
            first_name = folder_name.split()[0]  # Extract first name
            destination_path = os.path.join(output_folder, folder_name)
            os.makedirs(destination_path, exist_ok=True)
            
            for idx, file_name in enumerate(os.listdir(folder_path), start=1):
                source_file = os.path.join(folder_path, file_name)
                new_file_name = f"{first_name}_{idx}.jpg"
                destination_file = os.path.join(destination_path, new_file_name)
                destination_file_inverted = os.path.join(destination_path, f"inverted_{new_file_name}")
                
                if os.path.isfile(source_file):
                    processed_image, inverted_image = preprocess_signature(source_file)
                    if processed_image is not None:
                        cv2.imwrite(destination_file, (processed_image * 255).astype(np.uint8))
                        cv2.imwrite(destination_file_inverted, (inverted_image * 255).astype(np.uint8))
                        
                        # Apply augmentasi dan simpan gambar baru
                        augmented_images = augment_image((processed_image * 255).astype(np.uint8))
                        for i, aug_img in enumerate(augmented_images):
                            cv2.imwrite(os.path.join(destination_path, f"aug_{i}_{new_file_name}"), aug_img)
                        
                        print(f"Processed and saved {new_file_name} and its augmented versions to {destination_path}")

# Contoh penggunaan
train_directory = "train"
test_directory = "test"
processed_train_directory = "processed_train"
processed_test_directory = "processed_test"
preprocess_all_images(train_directory, processed_train_directory)
preprocess_all_images(test_directory, processed_test_directory)
print("Semua preprocessing selesai.")
# Out:
# Processed and saved Lithania_1.jpg and its augmented versions to processed_train/Lithania
# Processed and saved Lithania_2.jpg and its augmented versions to processed_train/Lithania
# Processed and saved Lithania_3.jpg and its augmented versions to processed_train/Lithania
# Processed and saved Lithania_4.jpg and its augmented versions to processed_train/Lithania
# Processed and saved Lia_1.jpg and its augmented versions to processed_train/Lia Kurniawati
# Processed and saved Lia_2.jpg and its augmented versions to processed_train/Lia Kurniawati
# Processed and saved Lia_3.jpg and its augmented versions to processed_train/Lia Kurniawati
# Processed and saved Lia_4.jpg and its augmented versions to processed_train/Lia Kurniawati
# Processed and saved Mariati_1.jpg and its augmented versions to processed_train/Mariati unidayan
# Processed and saved Mariati_2.jpg and its augmented versions to processed_train/Mariati unidayan
# Processed and saved Mariati_3.jpg and its augmented versions to processed_train/Mariati unidayan
# Processed and saved Mariati_4.jpg and its augmented versions to processed_train/Mariati unidayan
# Processed and saved Putu_1.jpg and its augmented versions to processed_train/Putu Riva
# Processed and saved Putu_2.jpg and its augmented versions to processed_train/Putu Riva
# Processed and saved Putu_3.jpg and its augmented versions to processed_train/Putu Riva
# Processed and saved Putu_4.jpg and its augmented versions to processed_train/Putu Riva
# Processed and saved Ni_1.jpg and its augmented versions to processed_train/Ni Luh Ica Ardini
# Processed and saved Ni_2.jpg and its augmented versions to processed_train/Ni Luh Ica Ardini
# Processed and saved Ni_3.jpg and its augmented versions to processed_train/Ni Luh Ica Ardini
# Processed and saved Ni_4.jpg and its augmented versions to processed_train/Ni Luh Ica Ardini
# Processed and saved Nur_1.jpg and its augmented versions to processed_train/Nur Ilmi Fadilah
# Processed and saved Nur_2.jpg and its augmented versions to processed_train/Nur Ilmi Fadilah
# Processed and saved Nur_3.jpg and its augmented versions to processed_train/Nur Ilmi Fadilah
# Processed and saved Nur_4.jpg and its augmented versions to processed_train/Nur Ilmi Fadilah
# Processed and saved Fildzah_1.jpg and its augmented versions to processed_train/Fildzah Khalishah
# Processed and saved Fildzah_2.jpg and its augmented versions to processed_train/Fildzah Khalishah
# Processed and saved Fildzah_3.jpg and its augmented versions to processed_train/Fildzah Khalishah
# Processed and saved Fildzah_4.jpg and its augmented versions to processed_train/Fildzah Khalishah
# Processed and saved Muhammad_1.jpg and its augmented versions to processed_train/Muhammad Azriel Saktiawan
# Processed and saved Muhammad_2.jpg and its augmented versions to processed_train/Muhammad Azriel Saktiawan
# Processed and saved Muhammad_3.jpg and its augmented versions to processed_train/Muhammad Azriel Saktiawan
# Processed and saved Muhammad_4.jpg and its augmented versions to processed_train/Muhammad Azriel Saktiawan
# Processed and saved Khairunnisa_1.jpg and its augmented versions to processed_train/Khairunnisa
# Processed and saved Khairunnisa_2.jpg and its augmented versions to processed_train/Khairunnisa
# Processed and saved Khairunnisa_3.jpg and its augmented versions to processed_train/Khairunnisa
# Processed and saved Khairunnisa_4.jpg and its augmented versions to processed_train/Khairunnisa
# Processed and saved Dewi_1.jpg and its augmented versions to processed_train/Dewi Titania Randa
# Processed and saved Dewi_2.jpg and its augmented versions to processed_train/Dewi Titania Randa
# Processed and saved Dewi_3.jpg and its augmented versions to processed_train/Dewi Titania Randa
# Processed and saved Dewi_4.jpg and its augmented versions to processed_train/Dewi Titania Randa
# Processed and saved Ishaq_1.jpg and its augmented versions to processed_train/Ishaq usn
# Processed and saved Ishaq_2.jpg and its augmented versions to processed_train/Ishaq usn
# Processed and saved Ishaq_3.jpg and its augmented versions to processed_train/Ishaq usn
# Processed and saved Ishaq_4.jpg and its augmented versions to processed_train/Ishaq usn
# Processed and saved Putri_1.jpg and its augmented versions to processed_train/Putri Angraini Aziz
# Processed and saved Putri_2.jpg and its augmented versions to processed_train/Putri Angraini Aziz
# Processed and saved Putri_3.jpg and its augmented versions to processed_train/Putri Angraini Aziz
# Processed and saved Putri_4.jpg and its augmented versions to processed_train/Putri Angraini Aziz
# Processed and saved Muh._1.jpg and its augmented versions to processed_train/Muh. Falah Mubaraq
# Processed and saved Muh._2.jpg and its augmented versions to processed_train/Muh. Falah Mubaraq
# Processed and saved Muh._3.jpg and its augmented versions to processed_train/Muh. Falah Mubaraq
# Processed and saved Muh._4.jpg and its augmented versions to processed_train/Muh. Falah Mubaraq
# Processed and saved Hashimatul_1.jpg and its augmented versions to processed_train/Hashimatul Zaria
# Processed and saved Hashimatul_2.jpg and its augmented versions to processed_train/Hashimatul Zaria
# Processed and saved Hashimatul_3.jpg and its augmented versions to processed_train/Hashimatul Zaria
# Processed and saved Hashimatul_4.jpg and its augmented versions to processed_train/Hashimatul Zaria
# Processed and saved Andi_1.jpg and its augmented versions to processed_train/Andi ahmad afiq
# Processed and saved Andi_2.jpg and its augmented versions to processed_train/Andi ahmad afiq
# Processed and saved Andi_3.jpg and its augmented versions to processed_train/Andi ahmad afiq
# Processed and saved Andi_4.jpg and its augmented versions to processed_train/Andi ahmad afiq
# Processed and saved Ikbal_1.jpg and its augmented versions to processed_train/Ikbal
# Processed and saved Ikbal_2.jpg and its augmented versions to processed_train/Ikbal
# Processed and saved Ikbal_3.jpg and its augmented versions to processed_train/Ikbal
# Processed and saved Ikbal_4.jpg and its augmented versions to processed_train/Ikbal
# Processed and saved Ainun_1.jpg and its augmented versions to processed_train/Ainun Putri
# Processed and saved Ainun_2.jpg and its augmented versions to processed_train/Ainun Putri
# Processed and saved Ainun_3.jpg and its augmented versions to processed_train/Ainun Putri
# Processed and saved Ainun_4.jpg and its augmented versions to processed_train/Ainun Putri
# Processed and saved Affan_1.jpg and its augmented versions to processed_train/Affan Haidar
# Processed and saved Affan_2.jpg and its augmented versions to processed_train/Affan Haidar
# Processed and saved Affan_3.jpg and its augmented versions to processed_train/Affan Haidar
# Processed and saved Affan_4.jpg and its augmented versions to processed_train/Affan Haidar
# Processed and saved Prety_1.jpg and its augmented versions to processed_train/Prety Maharani Utami
# Processed and saved Prety_2.jpg and its augmented versions to processed_train/Prety Maharani Utami
# Processed and saved Prety_3.jpg and its augmented versions to processed_train/Prety Maharani Utami
# Processed and saved Prety_4.jpg and its augmented versions to processed_train/Prety Maharani Utami
# Processed and saved Ni_1.jpg and its augmented versions to processed_train/Ni Made Sri Ulandari
# Processed and saved Ni_2.jpg and its augmented versions to processed_train/Ni Made Sri Ulandari
# Processed and saved Ni_3.jpg and its augmented versions to processed_train/Ni Made Sri Ulandari
# Processed and saved Ni_4.jpg and its augmented versions to processed_train/Ni Made Sri Ulandari
# Processed and saved Mas_1.jpg and its augmented versions to processed_train/Mas Bilal
# Processed and saved Mas_2.jpg and its augmented versions to processed_train/Mas Bilal
# Processed and saved Mas_3.jpg and its augmented versions to processed_train/Mas Bilal
# Processed and saved Mas_4.jpg and its augmented versions to processed_train/Mas Bilal
# Processed and saved Dwi_1.jpg and its augmented versions to processed_train/Dwi Octavia
# Processed and saved Dwi_2.jpg and its augmented versions to processed_train/Dwi Octavia
# Processed and saved Dwi_3.jpg and its augmented versions to processed_train/Dwi Octavia
# Processed and saved Dwi_4.jpg and its augmented versions to processed_train/Dwi Octavia
# Processed and saved Laode_1.jpg and its augmented versions to processed_train/Laode Sandi Yunus
# Processed and saved Laode_2.jpg and its augmented versions to processed_train/Laode Sandi Yunus
# Processed and saved Laode_3.jpg and its augmented versions to processed_train/Laode Sandi Yunus
# Processed and saved Laode_4.jpg and its augmented versions to processed_train/Laode Sandi Yunus
# Processed and saved Fadli_1.jpg and its augmented versions to processed_train/Fadli
# Processed and saved Fadli_2.jpg and its augmented versions to processed_train/Fadli
# Processed and saved Fadli_3.jpg and its augmented versions to processed_train/Fadli
# Processed and saved Fadli_4.jpg and its augmented versions to processed_train/Fadli
# Processed and saved Muh_1.jpg and its augmented versions to processed_train/Muh Luthfi
# Processed and saved Muh_2.jpg and its augmented versions to processed_train/Muh Luthfi
# Processed and saved Muh_3.jpg and its augmented versions to processed_train/Muh Luthfi
# Processed and saved Muh_4.jpg and its augmented versions to processed_train/Muh Luthfi
# Processed and saved Mursawal_1.jpg and its augmented versions to processed_train/Mursawal
# Processed and saved Mursawal_2.jpg and its augmented versions to processed_train/Mursawal
# Processed and saved Mursawal_3.jpg and its augmented versions to processed_train/Mursawal
# Processed and saved Mursawal_4.jpg and its augmented versions to processed_train/Mursawal
# Processed and saved Fiqram_1.jpg and its augmented versions to processed_train/Fiqram Faathir
# Processed and saved Fiqram_2.jpg and its augmented versions to processed_train/Fiqram Faathir
# Processed and saved Fiqram_3.jpg and its augmented versions to processed_train/Fiqram Faathir
# Processed and saved Fiqram_4.jpg and its augmented versions to processed_train/Fiqram Faathir
# Processed and saved Inka_1.jpg and its augmented versions to processed_train/Inka Sinulingga
# Processed and saved Inka_2.jpg and its augmented versions to processed_train/Inka Sinulingga
# Processed and saved Inka_3.jpg and its augmented versions to processed_train/Inka Sinulingga
# Processed and saved Inka_4.jpg and its augmented versions to processed_train/Inka Sinulingga
# Processed and saved Dinda_1.jpg and its augmented versions to processed_train/Dinda unidayan
# Processed and saved Dinda_2.jpg and its augmented versions to processed_train/Dinda unidayan
# Processed and saved Dinda_3.jpg and its augmented versions to processed_train/Dinda unidayan
# Processed and saved Dinda_4.jpg and its augmented versions to processed_train/Dinda unidayan
# Processed and saved Andi._1.jpg and its augmented versions to processed_train/Andi. Dwi Yuniarti. H
# Processed and saved Andi._2.jpg and its augmented versions to processed_train/Andi. Dwi Yuniarti. H
# Processed and saved Andi._3.jpg and its augmented versions to processed_train/Andi. Dwi Yuniarti. H
# Processed and saved Andi._4.jpg and its augmented versions to processed_train/Andi. Dwi Yuniarti. H
# Processed and saved Githa_1.jpg and its augmented versions to processed_train/Githa
# Processed and saved Githa_2.jpg and its augmented versions to processed_train/Githa
# Processed and saved Githa_3.jpg and its augmented versions to processed_train/Githa
# Processed and saved Githa_4.jpg and its augmented versions to processed_train/Githa
# Processed and saved Bayu_1.jpg and its augmented versions to processed_train/Bayu Adi
# Processed and saved Bayu_2.jpg and its augmented versions to processed_train/Bayu Adi
# Processed and saved Bayu_3.jpg and its augmented versions to processed_train/Bayu Adi
# Processed and saved Bayu_4.jpg and its augmented versions to processed_train/Bayu Adi
# Processed and saved Lithania_1.jpg and its augmented versions to processed_test/Lithania
# Processed and saved Lithania_2.jpg and its augmented versions to processed_test/Lithania
# Processed and saved Lia_1.jpg and its augmented versions to processed_test/Lia Kurniawati
# Processed and saved Lia_2.jpg and its augmented versions to processed_test/Lia Kurniawati
# Processed and saved Mariati_1.jpg and its augmented versions to processed_test/Mariati unidayan
# Processed and saved Mariati_2.jpg and its augmented versions to processed_test/Mariati unidayan
# Processed and saved Putu_1.jpg and its augmented versions to processed_test/Putu Riva
# Processed and saved Putu_2.jpg and its augmented versions to processed_test/Putu Riva
# Processed and saved Ni_1.jpg and its augmented versions to processed_test/Ni Luh Ica Ardini
# Processed and saved Ni_2.jpg and its augmented versions to processed_test/Ni Luh Ica Ardini
# Processed and saved Nur_1.jpg and its augmented versions to processed_test/Nur Ilmi Fadilah
# Processed and saved Nur_2.jpg and its augmented versions to processed_test/Nur Ilmi Fadilah
# Processed and saved Fildzah_1.jpg and its augmented versions to processed_test/Fildzah Khalishah
# Processed and saved Fildzah_2.jpg and its augmented versions to processed_test/Fildzah Khalishah
# Processed and saved Muhammad_1.jpg and its augmented versions to processed_test/Muhammad Azriel Saktiawan
# Processed and saved Muhammad_2.jpg and its augmented versions to processed_test/Muhammad Azriel Saktiawan
# Processed and saved Khairunnisa_1.jpg and its augmented versions to processed_test/Khairunnisa
# Processed and saved Khairunnisa_2.jpg and its augmented versions to processed_test/Khairunnisa
# Processed and saved Dewi_1.jpg and its augmented versions to processed_test/Dewi Titania Randa
# Processed and saved Ishaq_1.jpg and its augmented versions to processed_test/Ishaq usn
# Processed and saved Ishaq_2.jpg and its augmented versions to processed_test/Ishaq usn
# Processed and saved Putri_1.jpg and its augmented versions to processed_test/Putri Angraini Aziz
# Processed and saved Putri_2.jpg and its augmented versions to processed_test/Putri Angraini Aziz
# Processed and saved Muh._1.jpg and its augmented versions to processed_test/Muh. Falah Mubaraq
# Processed and saved Muh._2.jpg and its augmented versions to processed_test/Muh. Falah Mubaraq
# Processed and saved Hashimatul_1.jpg and its augmented versions to processed_test/Hashimatul Zaria
# Processed and saved Hashimatul_2.jpg and its augmented versions to processed_test/Hashimatul Zaria
# Processed and saved Andi_1.jpg and its augmented versions to processed_test/Andi ahmad afiq
# Processed and saved Andi_2.jpg and its augmented versions to processed_test/Andi ahmad afiq
# Processed and saved Ikbal_1.jpg and its augmented versions to processed_test/Ikbal
# Processed and saved Ikbal_2.jpg and its augmented versions to processed_test/Ikbal
# Processed and saved Ainun_1.jpg and its augmented versions to processed_test/Ainun Putri
# Processed and saved Ainun_2.jpg and its augmented versions to processed_test/Ainun Putri
# Processed and saved Affan_1.jpg and its augmented versions to processed_test/Affan Haidar
# Processed and saved Affan_2.jpg and its augmented versions to processed_test/Affan Haidar
# Processed and saved Prety_1.jpg and its augmented versions to processed_test/Prety Maharani Utami
# Processed and saved Prety_2.jpg and its augmented versions to processed_test/Prety Maharani Utami
# Processed and saved Ni_1.jpg and its augmented versions to processed_test/Ni Made Sri Ulandari
# Processed and saved Ni_2.jpg and its augmented versions to processed_test/Ni Made Sri Ulandari
# Processed and saved Mas_1.jpg and its augmented versions to processed_test/Mas Bilal
# Processed and saved Mas_2.jpg and its augmented versions to processed_test/Mas Bilal
# Processed and saved Dwi_1.jpg and its augmented versions to processed_test/Dwi Octavia
# Processed and saved Dwi_2.jpg and its augmented versions to processed_test/Dwi Octavia
# Processed and saved Laode_1.jpg and its augmented versions to processed_test/Laode Sandi Yunus
# Processed and saved Laode_2.jpg and its augmented versions to processed_test/Laode Sandi Yunus
# Processed and saved Fadli_1.jpg and its augmented versions to processed_test/Fadli
# Processed and saved Fadli_2.jpg and its augmented versions to processed_test/Fadli
# Processed and saved Muh_1.jpg and its augmented versions to processed_test/Muh Luthfi
# Processed and saved Muh_2.jpg and its augmented versions to processed_test/Muh Luthfi
# Processed and saved Mursawal_1.jpg and its augmented versions to processed_test/Mursawal
# Processed and saved Mursawal_2.jpg and its augmented versions to processed_test/Mursawal
# Processed and saved Fiqram_1.jpg and its augmented versions to processed_test/Fiqram Faathir
# Processed and saved Fiqram_2.jpg and its augmented versions to processed_test/Fiqram Faathir
# Processed and saved Inka_1.jpg and its augmented versions to processed_test/Inka Sinulingga
# Processed and saved Inka_2.jpg and its augmented versions to processed_test/Inka Sinulingga
# Processed and saved Dinda_1.jpg and its augmented versions to processed_test/Dinda unidayan
# Processed and saved Dinda_2.jpg and its augmented versions to processed_test/Dinda unidayan
# Processed and saved Andi._1.jpg and its augmented versions to processed_test/Andi. Dwi Yuniarti. H
# Processed and saved Andi._2.jpg and its augmented versions to processed_test/Andi. Dwi Yuniarti. H
# Processed and saved Githa_1.jpg and its augmented versions to processed_test/Githa
# Processed and saved Githa_2.jpg and its augmented versions to processed_test/Githa
# Processed and saved Bayu_1.jpg and its augmented versions to processed_test/Bayu Adi
# Processed and saved Bayu_2.jpg and its augmented versions to processed_test/Bayu Adi
# Semua preprocessing selesai.
